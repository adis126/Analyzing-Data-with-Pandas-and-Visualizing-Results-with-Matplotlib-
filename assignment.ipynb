# %%
# ==============================================================
# Assignment: Data Loading, Analysis, and Visualization
# Objective: Use pandas & matplotlib for data exploration
# ==============================================================

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# --------------------------------------------------------------
# Task 1: Load and Explore the Dataset
# --------------------------------------------------------------

try:
    # Load Iris dataset directly from sklearn
    iris = load_iris(as_frame=True)
    df = iris.frame  # Convert to pandas DataFrame
    df['species'] = df['target'].map(dict(enumerate(iris.target_names)))

    print("✅ Dataset loaded successfully!\n")
except Exception as e:
    print(f"❌ Error loading dataset: {e}")

# Display first few rows
print("🔹 First 5 rows of the dataset:")
display(df.head())

# Check structure, data types, and missing values
print("\n🔹 Dataset Info:")
print(df.info())

print("\n🔹 Missing values per column:")
print(df.isnull().sum())

# Clean dataset (Iris has no missing values, but we’ll handle anyway)
df = df.dropna()
# Out:
# ✅ Dataset loaded successfully!
#
# 🔹 First 5 rows of the dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target species
# 0       0  setosa
# 1       0  setosa
# 2       0  setosa
# 3       0  setosa
# 4       0  setosa
# 🔹 Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
# ...

# %%
# --------------------------------------------------------------
# Task 2: Basic Data Analysis
# --------------------------------------------------------------

print("\n🔹 Basic Statistics:")
display(df.describe())

# Grouping: average petal length by species
print("\n🔹 Average Petal Length by Species:")
grouped = df.groupby("species")["petal length (cm)"].mean()
print(grouped)

# Interesting finding
print("\n📌 Observation: Setosa species has noticeably smaller petals compared to Versicolor and Virginica.")
# Out:
# 🔹 Basic Statistics:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000
# 🔹 Average Petal Length by Species:
# species
# ...

# %%
# --------------------------------------------------------------
# Task 3: Data Visualization
# --------------------------------------------------------------

plt.style.use("seaborn-v0_8")

# 1. Line Chart (trend of sepal length across rows as an example of sequence)
plt.figure(figsize=(8,5))
plt.plot(df.index, df["sepal length (cm)"], label="Sepal Length")
plt.title("Trend of Sepal Length in Dataset")
plt.xlabel("Sample Index")
plt.ylabel("Sepal Length (cm)")
plt.legend()
plt.show()

# 2. Bar Chart (average petal length per species)
plt.figure(figsize=(7,5))
grouped.plot(kind="bar", color=["#ff9999","#66b3ff","#99ff99"])
plt.title("Average Petal Length by Species")
plt.xlabel("Species")
plt.ylabel("Avg Petal Length (cm)")
plt.show()

# 3. Histogram (distribution of sepal width)
plt.figure(figsize=(7,5))
plt.hist(df["sepal width (cm)"], bins=15, color="#66b3ff", edgecolor="black")
plt.title("Distribution of Sepal Width")
plt.xlabel("Sepal Width (cm)")
plt.ylabel("Frequency")
plt.show()

# 4. Scatter Plot (sepal length vs petal length)
plt.figure(figsize=(7,5))
sns.scatterplot(data=df, x="sepal length (cm)", y="petal length (cm)", hue="species", palette="Set1")
plt.title("Sepal Length vs Petal Length by Species")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Petal Length (cm)")
plt.legend(title="Species")
plt.show()

print("\n✅ Analysis complete! Plots displayed successfully.")
# Out:
# ✅ Analysis complete! Plots displayed successfully.
